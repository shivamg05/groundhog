# %% [markdown]
# #🦫 Groundhog Autonomous Web Agent
#
# ##Run the following cells to start up the Gradio App and use the agent!
#
# ####Before running, set the runtime type to a T4 GPU for best performance.

# %% [markdown]
# ###Clone repo

# %%
# !git clone https://github.com/shivamg05/groundhog.git
# %cd groundhog

# %% [markdown]
# ###Install requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ###Install Chrome

# %%
# !wget -q -O - https://dl-ssl.google.com/linux/linux_signing_key.pub | apt-key add -
# !sh -c 'echo "deb [arch=amd64] http://dl.google.com/linux/chrome/deb/ stable main" >> /etc/apt/sources.list.d/google-chrome.list'
# !apt-get -y update
# !apt-get install -y google-chrome-stable

# %% [markdown]
# ###Launch groundhog and click the link!
# ####Startup + first prompt may take a while

# %%
# !python gradio_app.py
